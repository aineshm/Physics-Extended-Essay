# %%
deg10 = [.12,.13,.11,.14,.10,.15,.13]
deg20 = [.31,.32,.30,.29,.31,.32,.28]
deg30 = [.47,.45,.45,.45,.46,.47,.49]
deg40 = [.42,.41,.38,.44,.43,.42,.42]
deg50 = [.36,.34,.35,.36,.35,.37,.33]
deg60 = [.29,.36,.30,.34,.32,.33,.28]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
y = deg10
x = [10,10,10,10,10,10,10]
y2= deg20
x2 = [20,20,20,20,20,20,20]
plt.scatter(x,y)
plt.scatter(x2,y2)

x3 = [30,30,30,30,30,30,30]
y3 = deg30
plt.scatter(x3,y3)

x4 = [40,40,40,40,40,40,40]
y4 = deg40
plt.scatter(x4,y4)

x5 = [50,50,50,50,50,50,50]
y5 = deg50
plt.scatter(x5,y5)

x6 = [60,60,60,60,60,60,60]
y6 = deg60
plt.scatter(x6,y6)

plt.title('Angle of Racket vs Distance Travelled')
plt.xlabel('Angle of Racket / \u00b0')
plt.ylabel('Horizontal Distance Travelled / m')

plt.show()

# %%
deg1 = np.array(deg10)
deg10
# Out:
# [0.12, 0.13, 0.11, 0.14, 0.1, 0.15, 0.13]

# %%
deg2 = np.array(deg20)
deg3 = np.array(deg30)
deg4 = np.array(deg40)
deg5 = np.array(deg50)
deg6 = np.array(deg60)

# %%
def meanfn(x):
    print(round(x.mean(),3))

# %%
list1 = [deg1,deg2,deg3,deg4,deg5,deg6]
for i in list1:
    meanfn(i)
# Out:
# 0.126
# 0.304
# 0.463
# 0.417
# 0.351
# 0.317

# %%
def unc(x):
    print(round((x.max()-x.min())/2,3))

for i in list1:
    unc(i)
# Out:
# 0.025
# 0.02
# 0.02
# 0.03
# 0.02
# 0.04
